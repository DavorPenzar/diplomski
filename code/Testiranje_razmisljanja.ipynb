# %% [markdown]
# # Testiranje razmišljanja

# %%
import copy
import math
import numbers

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import scipy.sparse as sp
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
from script import *

# %% [markdown]
# ## Jednakostranični trokut

# %%
O = triang()

# %%
O.shape
# Out:
# (50, 43)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

ax.set_aspect('equal')

show_func(O, ax = ax, how = 'contourf')

plt.show()

# %%
l, u = eigenfunc(O)

# %%
l.size
# Out:
# 1004

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

ax.plot(l)
plt.show()

# %% [markdown]
# Jednakostranični trokut ima jako *ružnu* prvu svojstvenu funkciju &mdash; uopće ne izgleda dvaput diferencijabilno.

# %%
fig = plt.figure(figsize = (16, 9))

ax0 = fig.add_subplot(121, projection = '3d')
ax1 = fig.add_subplot(122)

ax1.set_aspect('equal')

show_func(u[0], ax = ax0, how = 'plot_surface')
show_func(u[0], ax = ax1, how = 'contourf')

print(l[0])

plt.show()
# Out:
# 0.021446992817342258

# %% [markdown]
# ## Krug

# %%
O = ellips()

# %%
O.shape
# Out:
# (50, 50)

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

ax.set_aspect('equal')

show_func(O, ax = ax, how = 'contourf')

plt.show()

# %%
l, u = eigenfunc(O)

# %%
l.size
# Out:
# 1876

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

ax.plot(l)
plt.show()

# %% [markdown]
# Krug, za razliku od jednakostraničnog trokuta, ima puno ljepšu i glatkiju prvu svojstvenu funkciju. Aproksimacija dobivena ovim računom izgleda prilično uvjerljivo.

# %%
fig = plt.figure(figsize = (16, 9))

ax0 = fig.add_subplot(121, projection = '3d')
ax1 = fig.add_subplot(122)

ax1.set_aspect('equal')

show_func(u[0], ax = ax0, how = 'plot_surface')
show_func(u[0], ax = ax1, how = 'contourf')

print(l[0])

plt.show()
# Out:
# 0.009385542383562673
